# %% [markdown]
# # Group Chat

# %% [markdown]
# ## Problem Statement
# 1. **New Project Focus**: A mobile gaming company is developing a game for PS5, requiring new expertise.
#
# 2. **HR Role**: The HR team is responsible for determining hiring requirements by collaborating with relevant departments.
#
# 3. **Agentic System**: Implement a group chat system where HR initiates discussions with a Group Chat Manager to gather hiring needs from team members.

# %%
# Import the libraries
import autogen
from autogen import ConversableAgent, GroupChat, GroupChatManager
from IPython.display import Markdown, display
# Out:
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in LLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in AnthropicLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in BedrockLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in CerebrasLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in GeminiLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in GroqLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in OllamaLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in OpenAILLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in AzureOpenAILLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in DeepSeekLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in CohereLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in MistralLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(
# D:\software\Lib\site-packages\pydantic\_internal\_fields.py:132: UserWarning: Field "model_client_cls" in TogetherLLMConfigEntry has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
from getpass import getpass
OPENAI_KEY = getpass("Enter your api key here : ")
# Out:
# Enter your api key here :  ········

# %%
import os
os.environ["OPENAI_API_KEY"] = OPENAI_KEY

# %%
# configuration for LLM
config_list = {
    "config_list": [{"model": "gpt-4o-mini"}]
}

# %%
hr_agent = ConversableAgent(
    "hr_agent",
    system_message="""You are the head of HR in a company. The company is initiating the development of
                    a new B2C tech product and aims to assemble a dedicated team for this project.
                    Gather the hiring requirements from different departments as needed.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
product_agent = ConversableAgent(
    "product_agent",
    system_message="""You are the Head of Product at a company developing a new B2C tech product.
        Your goal is to communicate with the HR department to outline the hiring requirements for assembling a
        dedicated Product management team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
engineering_agent = ConversableAgent(
    "engineering_agent",
    system_message="""You are the Head of Engineering at a company developing a new B2C tech product.
        Your goal is to communicate with the HR department to outline the hiring requirements for assembling a
        dedicated engineering team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
marketing_agent = ConversableAgent(
    "marketing_agent",
    system_message="""You are the Head of Marketing at a company developing a new B2C tech product.
        Your goal is to communicate with the HR department to outline the hiring requirements for assembling a
        dedicated marketing team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
customer_support_agent = ConversableAgent(
    "customer_support_agent",
    system_message="""You are the Head of Customer support at a company developing a new B2C tech product.
        Your goal is to communicate with the HR department to outline the hiring requirements for assembling a
        dedicated customer support team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %% [markdown]
# - The selection criteria is auto.
# - Max-round = 5, means the conversation will go five rounds.

# %%
group_chat = GroupChat(
    agents=[customer_support_agent, product_agent, engineering_agent, marketing_agent],
    messages=[],
    max_round= 5,
    speaker_selection_method='auto',
    select_speaker_auto_llm_config=config_list
)

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
)

# %%
chat_result = hr_agent.initiate_chat(
    group_chat_manager,
    message="A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product",
    summary_method="last_msg",
)
# Out:
# hr_agent (to chat_manager):
#
# A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product
#
# --------------------------------------------------------------------------------
#
# Next speaker: product_agent
#
# product_agent (to chat_manager):
#
# Subject: Hiring Requirements for Product Management Team - New PS4 Game Development
#
# Dear HR Team,
#
# As we initiate the development of our new mobile game designed for PS4, it's crucial that we assemble a dedicated product management team with the right expertise to ensure successful product delivery. Below are the key roles, qualifications, skills, and budget needed for this initiative:
#
# ### Key Roles and Requirements
#
# 1. **Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor's degree in Business, Marketing, Game Design, or a related field.
#      - 3-5 years of experience in product management, particularly in gaming or tech.
#    - **Skills**:
#      - Strong understanding of game development processes and the gaming market.
#      - Excellent communication and leadership skills.
#      - Data-driven decision making and analytical skills.
#      - Agile project management experience.
#
# 2. **Associate Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in relevant field or equivalent work experience.
#      - 1-3 years of experience in product management or related roles.
#    - **Skills**:
#      - Familiarity with game development and consumer insights.
#      - Strong problem-solving skills and attention to detail.
#      - Ability to collaborate with cross-functional teams.
#
# 3. **User Experience (UX) Designer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Human-Computer Interaction, or related field.
#      - 3+ years of experience in UX/UI design for games or software.
#    - **Skills**:
#      - Proficient in wireframing and prototyping tools (Sketch, Figma, etc.).
#      - Strong understanding of user-centered design principles.
#      - Ability to conduct user research and testing.
#
# 4. **Game Analyst (1 Position)**
#    - **Qualifications**:
#      - Bachelor's degree in Data Science, Statistics, Game Design, or related field.
#      - 2-4 years of experience in game analytics or related analysis.
#    - **Skills**:
#      - Proficient in analytical tools (SQL, Tableau, etc.).
#      - Strong background in game monetization strategies.
#      - Ability to generate insights from player behaviour data.
#
# ### Budget
#
# 1. **Salaries**:
#    - Product Managers: $90,000 - $120,000 each
#    - Associate Product Managers: $70,000 - $90,000 each
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 2 Product Managers: $240,000 - $240,000
#    - For 2 Associate Product Managers: $140,000 - $180,000
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#    - **Overall Total**: $700,000 - $865,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# In summary, we aim to build a cross-functional team that combines product management expertise with design and analytical skills. This structured approach will ensure that we efficiently address market needs and successfully launch our new game.
#
# Please let me know if you need any further information or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Product
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: engineering_agent
#
# engineering_agent (to chat_manager):
#
# Subject: Hiring Requirements for Engineering Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we embark on the development of our new B2C tech product, it’s essential to assemble a skilled engineering team to drive this initiative forward. Below are the key roles, qualifications, skills, and budgetary considerations required for the team.
#
# ### Key Roles and Requirements
#
# 1. **Software Engineer (3 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 3-5 years of experience in software development.
#    - **Skills**:
#      - Proficiency in programming languages (e.g., Java, Python, JavaScript).
#      - Experience with web and mobile application development.
#      - Familiarity with version control systems (e.g., Git).
#      - Understanding of RESTful APIs and microservices architecture.
#
# 2. **DevOps Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, IT, or related field.
#      - 3-5 years of experience in DevOps or systems administration.
#    - **Skills**:
#      - Experience with cloud services (AWS, Azure, GCP).
#      - Proficiency in CI/CD tools (e.g., Jenkins, GitLab CI).
#      - Strong scripting skills (e.g., Bash, Python).
#      - Familiarity with container technologies (Docker, Kubernetes).
#
# 3. **UI/UX Developer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Computer Science, or related field.
#      - 2-4 years of experience in UI/UX design for web/mobile applications.
#    - **Skills**:
#      - Proficiency in design tools (e.g., Adobe XD, Figma).
#      - Strong understanding of user-centered design principles.
#      - Ability to collaborate with developers to implement designs effectively.
#
# 4. **Quality Assurance Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 2-4 years of experience in software quality assurance.
#    - **Skills**:
#      - Experience with automated testing frameworks (e.g., Selenium, JUnit).
#      - Strong analytical and problem-solving skills.
#      - Familiarity with performance testing tools.
#
# ### Budget
#
# 1. **Salaries**:
#    - Software Engineers: $90,000 - $120,000 each
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 3 Software Engineers: $270,000 - $360,000
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#    - **Overall Total**: $620,000 - $780,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# Building a skilled engineering team is critical to the successful development of our new B2C product. This structured approach will ensure we attract the right talent with the necessary skills to bring our vision to life.
#
# Please let me know if you require further details or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Engineering
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: marketing_agent
#
# marketing_agent (to chat_manager):
#
# Subject: Hiring Requirements for Marketing Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we gear up for the launch of our new B2C tech product, it's imperative to build a dedicated marketing team capable of driving awareness, engagement, and customer acquisition. Below are the key roles, qualifications, skills, and budgetary considerations required for this initiative.
#
# ### Key Roles and Requirements
#
# 1. **Marketing Manager (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Marketing, Business, or a related field.
#      - 5+ years of experience in marketing, preferably in the tech or consumer goods sectors.
#    - **Skills**:
#      - Strong strategic planning and project management skills.
#      - Exceptional communication and presentation abilities.
#      - Proficiency in digital marketing channels (SEO, SEM, email marketing, social media).
#      - Experience with data analytics tools (Google Analytics, HubSpot).
#
# 2. **Content Marketing Specialist (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Marketing, Communications, or a related field.
#      - 2-4 years of experience in content creation and marketing.
#    - **Skills**:
#      - Exceptional writing and storytelling skills, with a focus on audience engagement.
#      - Understanding of content management systems (e.g., WordPress).
#      - Ability to develop multimedia content (blogs, videos, infographics).
#
# 3. **Social Media Manager (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Marketing, Communications, or a related field.
#      - 3-5 years of experience managing social media platforms in a business context.
#    - **Skills**:
#      - Proficient in social media strategy development and execution.
#      - Strong analytical skills to track and report on performance metrics.
#      - Excellent customer service skills to engage with users effectively.
#
# 4. **Digital Advertising Specialist (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Marketing, Advertising, or a related field.
#      - 3-5 years of experience in digital advertising, including PPC campaigns.
#    - **Skills**:
#      - Proficiency with advertising platforms (Google Ads, Facebook Ads).
#      - Strong data analysis and budget management capabilities.
#      - Up-to-date knowledge of digital marketing trends and best practices.
#
# ### Budget
#
# 1. **Salaries**:
#    - Marketing Manager: $90,000 - $120,000
#    - Content Marketing Specialist: $60,000 - $85,000
#    - Social Media Manager: $70,000 - $90,000
#    - Digital Advertising Specialist: $70,000 - $100,000
#
# 2. **Total Estimated Salary Budget**:
#    - Marketing Manager: $90,000 - $120,000
#    - Content Marketing Specialist: $60,000 - $85,000
#    - Social Media Manager: $70,000 - $90,000
#    - Digital Advertising Specialist: $70,000 - $100,000
#    - **Overall Total**: $290,000 - $395,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), marketing tools/subscriptions (e.g., Hootsuite, SEMrush), and potential training budgets.
#
# ### Summary
#
# In summary, building this dedicated marketing team will be crucial to the successful positioning and launch of our new B2C tech product. Each role is tailored to ensure we have the necessary skills to achieve our marketing objectives and engage our target audience effectively.
#
# Please let me know if you need further information or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Marketing
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: customer_support_agent
#
# customer_support_agent (to chat_manager):
#
# Subject: Hiring Requirements for Customer Support Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we prepare for the launch of our new B2C tech product, establishing a robust customer support team is vital to ensure a seamless customer experience and address user inquiries effectively. Below are the key roles, qualifications, skills, and budget needed for this initiative.
#
# ### Key Roles and Requirements
#
# 1. **Customer Support Manager (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Business, Communications, or a related field.
#      - 5+ years of experience in customer support or service management.
#    - **Skills**:
#      - Strong leadership and team management skills.
#      - Excellent communication and conflict-resolution abilities.
#      - Experience with customer support software and CRM tools (e.g., Zendesk, Salesforce).
#      - Ability to analyze metrics and feedback for continuous improvement.
#
# 2. **Customer Support Representatives (3 Positions)**
#    - **Qualifications**:
#      - High school diploma or equivalent; Bachelor’s degree is a plus.
#      - 1-3 years of experience in a customer service role, ideally in tech or B2C.
#    - **Skills**:
#      - Strong problem-solving skills and customer-centric mindset.
#      - Proficient in written and verbal communication.
#      - Familiarity with ticketing systems and customer support platforms.
#      - Ability to work collaboratively in a fast-paced environment.
#
# 3. **Technical Support Specialist (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, IT, or related field.
#      - 2-4 years of experience in technical support or a similar role.
#    - **Skills**:
#      - Strong technical knowledge of products and troubleshooting processes.
#      - Excellent interpersonal skills to explain technical issues clearly to users.
#      - Ability to create FAQs and support documentation based on customer inquiries.
#
# 4. **Customer Experience Analyst (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Business, Marketing, Data Analysis, or a related field.
#      - 2-4 years of experience in data analysis or customer experience roles.
#    - **Skills**:
#      - Proficient in data analysis tools (Excel, SQL, etc.) and customer feedback tools.
#      - Strong analytical and critical thinking skills to interpret data and identify trends.
#      - Ability to communicate insights effectively to stakeholders.
#
# ### Budget
#
# 1. **Salaries**:
#    - Customer Support Manager: $85,000 - $110,000
#    - Customer Support Representatives: $40,000 - $55,000 each
#    - Technical Support Specialist: $60,000 - $80,000
#    - Customer Experience Analyst: $70,000 - $90,000
#
# 2. **Total Estimated Salary Budget**:
#    - Customer Support Manager: $85,000 - $110,000
#    - For 3 Customer Support Representatives: $120,000 - $165,000
#    - Technical Support Specialist: $60,000 - $80,000
#    - Customer Experience Analyst: $70,000 - $90,000
#    - **Overall Total**: $435,000 - $545,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), customer support tools/software licenses, and potential training budgets.
#
# ### Summary
#
# Building a dedicated customer support team is essential for achieving high customer satisfaction and ensuring that we can effectively address user needs for our new B2C tech product. This structured approach will position us to deliver exceptional support and experience for our customers.
#
# Please let me know if you require any further details or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Customer Support
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (fd1aa8bf-8a02-40e1-9426-34c29ef5113f): Maximum rounds (5) reached

# %%
agent_name_to_find = "customer_support_agent"

# Iterate through the dictionary to find the last conversation for the specified agent
for agent, interactions in group_chat_manager.chat_messages.items():
    # Filter interactions by agent name
    filtered_interactions = [i for i in interactions if i.get("name") == agent_name_to_find]
    if filtered_interactions:
        # Print the last conversation's content
        print(filtered_interactions[-1]["content"])
        break
else:
    print("Agent not found or no interactions available.")
# Out:
# Subject: Hiring Requirements for Customer Support Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we prepare for the launch of our new B2C tech product, establishing a robust customer support team is vital to ensure a seamless customer experience and address user inquiries effectively. Below are the key roles, qualifications, skills, and budget needed for this initiative.
#
# ### Key Roles and Requirements
#
# 1. **Customer Support Manager (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Business, Communications, or a related field.
#      - 5+ years of experience in customer support or service management.
#    - **Skills**:
#      - Strong leadership and team management skills.
#      - Excellent communication and conflict-resolution abilities.
#      - Experience with customer support software and CRM tools (e.g., Zendesk, Salesforce).
#      - Ability to analyze metrics and feedback for continuous improvement.
#
# 2. **Customer Support Representatives (3 Positions)**
#    - **Qualifications**:
#      - High school diploma or equivalent; Bachelor’s degree is a plus.
#      - 1-3 years of experience in a customer service role, ideally in tech or B2C.
#    - **Skills**:
#      - Strong problem-solving skills and customer-centric mindset.
#      - Proficient in written and verbal communication.
#      - Familiarity with ticketing systems and customer support platforms.
#      - Ability to work collaboratively in a fast-paced environment.
#
# 3. **Technical Support Specialist (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, IT, or related field.
#      - 2-4 years of experience in technical support or a similar role.
#    - **Skills**:
#      - Strong technical knowledge of products and troubleshooting processes.
#      - Excellent interpersonal skills to explain technical issues clearly to users.
#      - Ability to create FAQs and support documentation based on customer inquiries.
#
# 4. **Customer Experience Analyst (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Business, Marketing, Data Analysis, or a related field.
#      - 2-4 years of experience in data analysis or customer experience roles.
#    - **Skills**:
#      - Proficient in data analysis tools (Excel, SQL, etc.) and customer feedback tools.
#      - Strong analytical and critical thinking skills to interpret data and identify trends.
#      - Ability to communicate insights effectively to stakeholders.
#
# ### Budget
#
# 1. **Salaries**:
#    - Customer Support Manager: $85,000 - $110,000
#    - Customer Support Representatives: $40,000 - $55,000 each
#    - Technical Support Specialist: $60,000 - $80,000
#    - Customer Experience Analyst: $70,000 - $90,000
#
# 2. **Total Estimated Salary Budget**:
#    - Customer Support Manager: $85,000 - $110,000
#    - For 3 Customer Support Representatives: $120,000 - $165,000
#    - Technical Support Specialist: $60,000 - $80,000
#    - Customer Experience Analyst: $70,000 - $90,000
#    - **Overall Total**: $435,000 - $545,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), customer support tools/software licenses, and potential training budgets.
#
# ### Summary
#
# Building a dedicated customer support team is essential for achieving high customer satisfaction and ensuring that we can effectively address user needs for our new B2C tech product. This structured approach will position us to deliver exceptional support and experience for our customers.
#
# Please let me know if you require any further details or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Customer Support
# [Your Company Name]
# [Your Contact Information]

# %% [markdown]
# # StateFlow

# %%
summarizer_agent = ConversableAgent(
    "summarizer_agent",
    system_message="""Summarize the received hiring requirements of all the departments, mentioning just the positions for each department""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %% [markdown]
# - Not accomodating the steps in case an agent throws an error,
# - And conditions under which a specific agent will be approached or ignored, etc.

# %%
def state_transition(last_speaker, groupchat):

    messages = groupchat.messages

    if last_speaker is hr_agent:
        return product_agent
    elif last_speaker is product_agent:
        if 'software' in messages[-1]['content']:
            return engineering_agent
        # If the product is software centric
        else:
            return marketing_agent
        if messages[-1]["content"] == "exitcode: 1":
            return engineering_agent
    elif last_speaker in [marketing_agent, engineering_agent]:
        return customer_support_agent
    elif last_speaker is customer_support_agent:
        return summarizer_agent
    elif last_speaker == summarizer_agent:
        return None

# %%
group_chat = GroupChat(
    agents=[product_agent, engineering_agent, marketing_agent, customer_support_agent, summarizer_agent],
    messages=[],
    max_round=10,
    speaker_selection_method=state_transition,
    select_speaker_auto_llm_config=config_list
)

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
)

# %%
chat_result = hr_agent.initiate_chat(
    group_chat_manager,
    message="A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product",
    summary_method="last_msg",
)
# Out:
# hr_agent (to chat_manager):
#
# A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product
#
# --------------------------------------------------------------------------------
#
# Next speaker: product_agent
#
# product_agent (to chat_manager):
#
# Subject: Hiring Requirements for Product Management Team - New PS4 Game Development
#
# Dear HR Team,
#
# As we initiate the development of our new mobile game designed for PS4, it's crucial that we assemble a dedicated product management team with the right expertise to ensure successful product delivery. Below are the key roles, qualifications, skills, and budget needed for this initiative:
#
# ### Key Roles and Requirements
#
# 1. **Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor's degree in Business, Marketing, Game Design, or a related field.
#      - 3-5 years of experience in product management, particularly in gaming or tech.
#    - **Skills**:
#      - Strong understanding of game development processes and the gaming market.
#      - Excellent communication and leadership skills.
#      - Data-driven decision making and analytical skills.
#      - Agile project management experience.
#
# 2. **Associate Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in relevant field or equivalent work experience.
#      - 1-3 years of experience in product management or related roles.
#    - **Skills**:
#      - Familiarity with game development and consumer insights.
#      - Strong problem-solving skills and attention to detail.
#      - Ability to collaborate with cross-functional teams.
#
# 3. **User Experience (UX) Designer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Human-Computer Interaction, or related field.
#      - 3+ years of experience in UX/UI design for games or software.
#    - **Skills**:
#      - Proficient in wireframing and prototyping tools (Sketch, Figma, etc.).
#      - Strong understanding of user-centered design principles.
#      - Ability to conduct user research and testing.
#
# 4. **Game Analyst (1 Position)**
#    - **Qualifications**:
#      - Bachelor's degree in Data Science, Statistics, Game Design, or related field.
#      - 2-4 years of experience in game analytics or related analysis.
#    - **Skills**:
#      - Proficient in analytical tools (SQL, Tableau, etc.).
#      - Strong background in game monetization strategies.
#      - Ability to generate insights from player behaviour data.
#
# ### Budget
#
# 1. **Salaries**:
#    - Product Managers: $90,000 - $120,000 each
#    - Associate Product Managers: $70,000 - $90,000 each
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 2 Product Managers: $240,000 - $240,000
#    - For 2 Associate Product Managers: $140,000 - $180,000
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#    - **Overall Total**: $700,000 - $865,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# In summary, we aim to build a cross-functional team that combines product management expertise with design and analytical skills. This structured approach will ensure that we efficiently address market needs and successfully launch our new game.
#
# Please let me know if you need any further information or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Product
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: engineering_agent
#
# engineering_agent (to chat_manager):
#
# Subject: Hiring Requirements for Engineering Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we embark on the development of our new B2C tech product, it’s essential to assemble a skilled engineering team to drive this initiative forward. Below are the key roles, qualifications, skills, and budgetary considerations required for the team.
#
# ### Key Roles and Requirements
#
# 1. **Software Engineer (3 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 3-5 years of experience in software development.
#    - **Skills**:
#      - Proficiency in programming languages (e.g., Java, Python, JavaScript).
#      - Experience with web and mobile application development.
#      - Familiarity with version control systems (e.g., Git).
#      - Understanding of RESTful APIs and microservices architecture.
#
# 2. **DevOps Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, IT, or related field.
#      - 3-5 years of experience in DevOps or systems administration.
#    - **Skills**:
#      - Experience with cloud services (AWS, Azure, GCP).
#      - Proficiency in CI/CD tools (e.g., Jenkins, GitLab CI).
#      - Strong scripting skills (e.g., Bash, Python).
#      - Familiarity with container technologies (Docker, Kubernetes).
#
# 3. **UI/UX Developer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Computer Science, or related field.
#      - 2-4 years of experience in UI/UX design for web/mobile applications.
#    - **Skills**:
#      - Proficiency in design tools (e.g., Adobe XD, Figma).
#      - Strong understanding of user-centered design principles.
#      - Ability to collaborate with developers to implement designs effectively.
#
# 4. **Quality Assurance Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 2-4 years of experience in software quality assurance.
#    - **Skills**:
#      - Experience with automated testing frameworks (e.g., Selenium, JUnit).
#      - Strong analytical and problem-solving skills.
#      - Familiarity with performance testing tools.
#
# ### Budget
#
# 1. **Salaries**:
#    - Software Engineers: $90,000 - $120,000 each
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 3 Software Engineers: $270,000 - $360,000
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#    - **Overall Total**: $620,000 - $780,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# Building a skilled engineering team is critical to the successful development of our new B2C product. This structured approach will ensure we attract the right talent with the necessary skills to bring our vision to life.
#
# Please let me know if you require further details or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Engineering
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: customer_support_agent
#
# customer_support_agent (to chat_manager):
#
# Subject: Hiring Requirements for Customer Support Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we prepare to launch our new B2C tech product, it’s vital to establish a dedicated customer support team aimed at delivering exceptional service to our users. Below are the key roles, qualifications, skills, and budgetary considerations for this initiative.
#
# ### Key Roles and Requirements
#
# 1. **Customer Support Manager (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Business, Communications, or a related field.
#      - 5+ years of experience in customer support, with at least 2 years in a managerial role.
#    - **Skills**:
#      - Strong leadership and team management abilities.
#      - Excellent communication and interpersonal skills.
#      - Ability to analyze and utilize customer feedback to improve processes.
#
# 2. **Customer Support Representatives (4 Positions)**
#    - **Qualifications**:
#      - High school diploma or equivalent; a Bachelor’s degree is a plus.
#      - 1-3 years of experience in a customer service role.
#    - **Skills**:
#      - Strong problem-solving abilities and customer-centric mindset.
#      - Proficiency in using support ticketing systems (e.g., Zendesk, Freshdesk).
#      - Excellent verbal and written communication skills.
#      - Ability to work in a fast-paced environment.
#
# 3. **Technical Support Specialist (2 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in Information Technology, Computer Science, or a related field.
#      - 2-4 years of technical support or IT help desk experience.
#    - **Skills**:
#      - Proficient knowledge of common operating systems and software applications.
#      - Strong troubleshooting and diagnostic skills.
#      - Ability to communicate technical information to non-technical users.
#
# ### Budget
#
# 1. **Salaries**:
#    - Customer Support Manager: $70,000 - $100,000
#    - Customer Support Representatives: $40,000 - $50,000 each
#    - Technical Support Specialists: $60,000 - $80,000 each
#
# 2. **Total Estimated Salary Budget**:
#    - Customer Support Manager: $70,000 - $100,000
#    - For 4 Customer Support Representatives: $160,000 - $200,000
#    - For 2 Technical Support Specialists: $120,000 - $160,000
#    - **Overall Total**: $350,000 - $460,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), support tools/software licenses, training, and onboarding costs.
#
# ### Summary
#
# The formation of a skilled customer support team is essential for the successful launch and ongoing success of our new B2C tech product. This structured hiring strategy will ensure we have the right talent in place to address customer inquiries effectively and enhance user satisfaction.
#
# Please let me know if you need any further information or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Customer Support
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: summarizer_agent
#
# summarizer_agent (to chat_manager):
#
# ### Summary of Hiring Requirements by Department
#
# #### Product Management Team
# 1. Product Manager (2 Positions)
# 2. Associate Product Manager (2 Positions)
# 3. User Experience (UX) Designer (1 Position)
# 4. Game Analyst (1 Position)
#
# #### Engineering Team
# 1. Software Engineer (3 Positions)
# 2. DevOps Engineer (1 Position)
# 3. UI/UX Developer (1 Position)
# 4. Quality Assurance Engineer (1 Position)
#
# #### Customer Support Team
# 1. Customer Support Manager (1 Position)
# 2. Customer Support Representatives (4 Positions)
# 3. Technical Support Specialist (2 Positions)
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (9b3fcb10-345b-4a62-8399-793575e0e4bd): No next speaker selected

# %%
chat_result = hr_agent.initiate_chat(
    group_chat_manager,
    message="A toothpaste company has decided to focus on a new mouthwash. Provide hiring requirements for this new product",
    summary_method="last_msg",
)
# Out:
# hr_agent (to chat_manager):
#
# A toothpaste company has decided to focus on a new mouthwash. Provide hiring requirements for this new product
#
# --------------------------------------------------------------------------------
#
# Next speaker: product_agent
#
# product_agent (to chat_manager):
#
# Subject: Hiring Requirements for Product Management Team for New Mouthwash Initiative
#
# Dear HR Team,
#
# As we embark on the development of our new mouthwash product, assembling a dedicated Product Management team is essential to ensure its success in the market. Below is a detailed outline of the key roles, qualifications, skills, and budget needed for this initiative.
#
# ### Key Roles:
#
# 1. **Product Manager (2 Positions)**
#    - **Qualifications:**
#      - Bachelor’s degree in Business Administration, Marketing, or a related field.
#      - 3-5 years of experience in product management or consumer goods.
#    - **Skills:**
#      - Strong analytical skills and experience with market research.
#      - Excellent communication and cross-functional collaboration.
#      - Familiarity with product lifecycle management.
#
# 2. **Market Research Analyst (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Marketing, Economics, or a related field.
#      - 2+ years of experience in market research or consumer insights.
#    - **Skills:**
#      - Proficient in data analysis tools (e.g., Excel, SPSS).
#      - Strong understanding of market segmentation and consumer behavior.
#      - Ability to present findings effectively.
#
# 3. **Regulatory Affairs Specialist (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in science (Biochemistry, Pharmacology, or related field).
#      - 3+ years of experience in regulatory affairs, especially in cosmetics or personal care products.
#    - **Skills:**
#      - Familiarity with regulatory frameworks for cosmetic products.
#      - Strong attention to detail and project management skills.
#      - Effective communicator with stakeholders.
#
# 4. **Marketing Specialist (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Marketing, Communications, or a related field.
#      - 2-4 years of experience in consumer marketing, specifically in personal care.
#    - **Skills:**
#      - Proven track record of developing marketing strategies.
#      - Strong creative skills and experience in digital marketing channels.
#      - Ability to manage campaigns from concept to execution.
#
# 5. **Product Designer (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Product Design, Industrial Design, or a related field.
#      - 3+ years of relevant experience in consumer product design.
#    - **Skills:**
#      - Proficient in design software (e.g., Adobe Creative Suite, CAD).
#      - Excellent understanding of user-centered design principles.
#      - Creative problem-solving skills to innovate product features.
#
# ### Budget Estimation:
#
# 1. **Recruitment Costs:**
#    - Advertising & Job Portals: $5,000
#    - Agency Fees (if applicable): $10,000
#
# 2. **Salaries:**
#    - Product Managers (2 x $90,000): $180,000
#    - Market Research Analyst: $60,000
#    - Regulatory Affairs Specialist: $80,000
#    - Marketing Specialist: $70,000
#    - Product Designer: $75,000
#    - **Total Salaries:** $465,000/year
#
# 3. **Onboarding & Training:**
#    - Estimated Costs: $15,000
#
# ### Total Estimated Budget: $485,000/year
#
# Please review this outline, and let’s discuss any adjustments or considerations as we move forward in recruiting for these positions. Your support will be vital for assembling a strong and effective Product Management team for our mouthwash project.
#
# Best regards,
#
# [Your Name]
# Head of Product
# [Company Name]
#
# --------------------------------------------------------------------------------
#
# Next speaker: engineering_agent
#
# engineering_agent (to chat_manager):
#
# Subject: Hiring Requirements for Engineering Team for New B2C Tech Product
#
# Dear HR Team,
#
# As we move forward with the development of our new B2C tech product, it is essential to assemble a dedicated engineering team that possesses the right expertise and skills to ensure successful delivery and innovation. Below is a detailed outline of the key roles, qualifications, skills, and budget needed for this initiative.
#
# ### Key Roles:
#
# 1. **Software Engineer (3 Positions)**
#    - **Qualifications:**
#      - Bachelor’s degree in Computer Science, Software Engineering, or a related field.
#      - 3-5 years of experience in software development.
#    - **Skills:**
#      - Proficiency in programming languages such as Java, Python, or JavaScript.
#      - Experience with web and mobile application development frameworks.
#      - Familiarity with Agile development methodologies.
#
# 2. **UI/UX Designer (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Design, Art, HCI, or a related field.
#      - 2-4 years of experience in user interface and user experience design.
#    - **Skills:**
#      - Proficiency in design and prototyping software (e.g., Figma, Sketch, Adobe XD).
#      - Strong understanding of user-centered design principles.
#      - Ability to conduct user research and usability testing.
#
# 3. **Quality Assurance Engineer (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Software Engineering, Computer Science, or a related field.
#      - 2-4 years of experience in QA testing, especially in B2C applications.
#    - **Skills:**
#      - Familiarity with automated testing tools (e.g., Selenium, JUnit).
#      - Strong analytical skills and attention to detail.
#      - Excellent troubleshooting and problem-solving skills.
#
# 4. **Data Analyst (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Data Science, Statistics, or a related field.
#      - 3+ years of experience in data analysis or a related field, preferably in consumer tech.
#    - **Skills:**
#      - Proficiency in analytics tools (e.g., SQL, R, Tableau).
#      - Strong aptitude for interpreting and analyzing data trends.
#      - Ability to communicate insights effectively to non-technical stakeholders.
#
# 5. **DevOps Engineer (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Computer Science or a related field.
#      - 3-5 years of experience in DevOps practices and tools.
#    - **Skills:**
#      - Proficiency in cloud services (e.g., AWS, Azure) and containerization tools (e.g., Docker, Kubernetes).
#      - Strong scripting skills and experience with CI/CD pipelines.
#      - Excellent problem-solving and communication skills.
#
# ### Budget Estimation:
#
# 1. **Recruitment Costs:**
#    - Advertising & Job Portals: $6,000
#    - Agency Fees (if applicable): $12,000
#
# 2. **Salaries:**
#    - Software Engineers (3 x $95,000): $285,000
#    - UI/UX Designer: $80,000
#    - Quality Assurance Engineer: $75,000
#    - Data Analyst: $90,000
#    - DevOps Engineer: $100,000
#    - **Total Salaries:** $630,000/year
#
# 3. **Onboarding & Training:**
#    - Estimated Costs: $20,000
#
# ### Total Estimated Budget: $668,000/year
#
# Please review this outline and let me know if you have any questions or require adjustments. Assembling this engineering team is crucial for the successful development and deployment of our B2C tech product.
#
# Best regards,
#
# [Your Name]
# Head of Engineering
# [Company Name]
#
# --------------------------------------------------------------------------------
#
# Next speaker: customer_support_agent
#
# customer_support_agent (to chat_manager):
#
# Subject: Hiring Requirements for Customer Support Team for New B2C Tech Product
#
# Dear HR Team,
#
# As we prepare for the launch of our new B2C tech product, it is critical to establish a dedicated Customer Support team focused on delivering exceptional service and support to our users. Below is a detailed outline of the key roles, qualifications, skills, and budget required for this initiative.
#
# ### Key Roles:
#
# 1. **Customer Support Manager (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Business, Communications, or a related field.
#      - 5+ years of experience in customer support management, preferably in tech.
#    - **Skills:**
#      - Strong leadership and team management skills.
#      - Experience in implementing customer support strategies.
#      - Excellent communication and interpersonal skills.
#
# 2. **Customer Support Representatives (4 Positions)**
#    - **Qualifications:**
#      - High school diploma or equivalent (Bachelor’s degree preferred).
#      - 1-3 years of experience in customer service or support roles.
#    - **Skills:**
#      - Strong verbal and written communication skills.
#      - Proficiency in CRM software (e.g., Zendesk, Salesforce).
#      - Problem-solving skills and the ability to handle challenging situations.
#
# 3. **Technical Support Specialist (2 Positions)**
#    - **Qualifications:**
#      - Bachelor’s degree in Computer Science, Information Technology, or a related field.
#      - 2-4 years of experience in technical support, preferably for software products.
#    - **Skills:**
#      - Strong troubleshooting skills and technical aptitude.
#      - Ability to explain technical issues to non-technical users.
#      - Experience with ticketing systems and remote support tools.
#
# 4. **Customer Experience Analyst (1 Position)**
#    - **Qualifications:**
#      - Bachelor’s degree in Marketing, Business, or a related field.
#      - 2-4 years of experience in customer experience, data analysis, or related fields.
#    - **Skills:**
#      - Proficiency in data analysis and reporting tools (e.g., Excel, Tableau).
#      - Strong analytical skills to identify trends and areas for improvement.
#      - Excellent presentation and communication skills.
#
# ### Budget Estimation:
#
# 1. **Recruitment Costs:**
#    - Advertising & Job Portals: $5,000
#    - Agency Fees (if applicable): $8,000
#
# 2. **Salaries:**
#    - Customer Support Manager: $80,000
#    - Customer Support Representatives (4 x $45,000): $180,000
#    - Technical Support Specialists (2 x $65,000): $130,000
#    - Customer Experience Analyst: $70,000
#    - **Total Salaries:** $460,000/year
#
# 3. **Onboarding & Training:**
#    - Estimated Costs: $15,000
#
# ### Total Estimated Budget: $488,000/year
#
# I kindly request your review of this outline, and I look forward to discussing any adjustments or considerations as we move forward in recruiting the right talent for our Customer Support team. Their role will be crucial in ensuring we provide top-notch support and satisfaction for our customers.
#
# Best regards,
#
# [Your Name]
# Head of Customer Support
# [Company Name]
#
# --------------------------------------------------------------------------------
#
# Next speaker: summarizer_agent
#
# summarizer_agent (to chat_manager):
#
# ### Summary of Hiring Requirements by Department
#
# #### Product Management Team
# 1. **Product Manager** (2 Positions)
# 2. **Market Research Analyst** (1 Position)
# 3. **Regulatory Affairs Specialist** (1 Position)
# 4. **Marketing Specialist** (1 Position)
# 5. **Product Designer** (1 Position)
#
# ---
#
# #### Engineering Team
# 1. **Software Engineer** (3 Positions)
# 2. **UI/UX Designer** (1 Position)
# 3. **Quality Assurance Engineer** (1 Position)
# 4. **Data Analyst** (1 Position)
# 5. **DevOps Engineer** (1 Position)
#
# ---
#
# #### Customer Support Team
# 1. **Customer Support Manager** (1 Position)
# 2. **Customer Support Representatives** (4 Positions)
# 3. **Technical Support Specialist** (2 Positions)
# 4. **Customer Experience Analyst** (1 Position)
#
# This summary captures the essential positions required across the Product Management, Engineering, and Customer Support teams for their respective initiatives.
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (105357ff-5330-4b9a-8cfc-634430f75c97): No next speaker selected

# %%
agent_name_to_find = "summarizer_agent"

# Iterate through the dictionary to find the last conversation for the specified agent
for agent, interactions in group_chat_manager.chat_messages.items():
    # Filter interactions by agent name
    filtered_interactions = [i for i in interactions if i.get("name") == agent_name_to_find]
    if filtered_interactions:
        # Print the last conversation's content
        print(filtered_interactions[-1]["content"])
        break
else:
    print("Agent not found or no interactions available.")
# Out:
# ### Summary of Hiring Requirements by Department
#
# #### Product Management Team
# 1. **Product Manager** (2 Positions)
# 2. **Market Research Analyst** (1 Position)
# 3. **Regulatory Affairs Specialist** (1 Position)
# 4. **Marketing Specialist** (1 Position)
# 5. **Product Designer** (1 Position)
#
# ---
#
# #### Engineering Team
# 1. **Software Engineer** (3 Positions)
# 2. **UI/UX Designer** (1 Position)
# 3. **Quality Assurance Engineer** (1 Position)
# 4. **Data Analyst** (1 Position)
# 5. **DevOps Engineer** (1 Position)
#
# ---
#
# #### Customer Support Team
# 1. **Customer Support Manager** (1 Position)
# 2. **Customer Support Representatives** (4 Positions)
# 3. **Technical Support Specialist** (2 Positions)
# 4. **Customer Experience Analyst** (1 Position)
#
# This summary captures the essential positions required across the Product Management, Engineering, and Customer Support teams for their respective initiatives.

# %% [markdown]
# # Nested Chat

# %%
digital_marketing_agent = ConversableAgent(
    "digital_marketing_agent",
    system_message="""You are the Digital Marketing Head at a company developing a new B2C tech product. You report to head of marketing.
        Your goal is to communicate with the Marketing head to outline the hiring requirements for assembling a
        digital marketing team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
creative_team_agent = ConversableAgent(
    "creative_team_agent",
    system_message="""You are the Creative Team Head at a company developing a new B2C tech product. You report to head of marketing.
        Your goal is to communicate with the Marketing head to outline the hiring requirements for assembling a
        creative team for this project. Clearly and concisely list the key roles, qualifications, and
        skills, and budget needed for this initiative.""",
    llm_config=config_list,
    human_input_mode="NEVER",
)

# %%
nested_chats = [
    {
        "recipient": digital_marketing_agent,
        "message": "Gather hiring requirements of your team for this product",
        "max_turns": 1,
        "summary_method": "reflection_with_llm",
    },
    {
        "recipient": creative_team_agent,
        "message": "Gather hiring requirements of your team for this product",
        "max_turns": 1,
        "summary_method": "last_msg",
    },
]

# %%
marketing_agent.register_nested_chats(
    nested_chats,
    trigger=lambda sender: sender not in [digital_marketing_agent, creative_team_agent],
)

# %%
def state_transition(last_speaker, groupchat):
    if last_speaker is hr_agent:
        return product_agent
    elif last_speaker is product_agent:
        return engineering_agent
    elif last_speaker is engineering_agent:
        return marketing_agent
    elif last_speaker is marketing_agent:
        return None

# %%
group_chat = GroupChat(
    agents=[product_agent, engineering_agent, marketing_agent],
    messages=[],
    max_round= 10,
    speaker_selection_method= state_transition,
    select_speaker_auto_llm_config=config_list
)

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
)

# %%
chat_result = hr_agent.initiate_chat(
    group_chat_manager,
    message="A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product",
    summary_method="last_msg",
)
# Out:
# hr_agent (to chat_manager):
#
# A gaming company focussed on mobiles games is launching a new game designed for PS4. Provide hiring requirements for this new product
#
# --------------------------------------------------------------------------------
#
# Next speaker: product_agent
#
# product_agent (to chat_manager):
#
# Subject: Hiring Requirements for Product Management Team - New PS4 Game Development
#
# Dear HR Team,
#
# As we initiate the development of our new mobile game designed for PS4, it's crucial that we assemble a dedicated product management team with the right expertise to ensure successful product delivery. Below are the key roles, qualifications, skills, and budget needed for this initiative:
#
# ### Key Roles and Requirements
#
# 1. **Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor's degree in Business, Marketing, Game Design, or a related field.
#      - 3-5 years of experience in product management, particularly in gaming or tech.
#    - **Skills**:
#      - Strong understanding of game development processes and the gaming market.
#      - Excellent communication and leadership skills.
#      - Data-driven decision making and analytical skills.
#      - Agile project management experience.
#
# 2. **Associate Product Manager (2 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in relevant field or equivalent work experience.
#      - 1-3 years of experience in product management or related roles.
#    - **Skills**:
#      - Familiarity with game development and consumer insights.
#      - Strong problem-solving skills and attention to detail.
#      - Ability to collaborate with cross-functional teams.
#
# 3. **User Experience (UX) Designer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Human-Computer Interaction, or related field.
#      - 3+ years of experience in UX/UI design for games or software.
#    - **Skills**:
#      - Proficient in wireframing and prototyping tools (Sketch, Figma, etc.).
#      - Strong understanding of user-centered design principles.
#      - Ability to conduct user research and testing.
#
# 4. **Game Analyst (1 Position)**
#    - **Qualifications**:
#      - Bachelor's degree in Data Science, Statistics, Game Design, or related field.
#      - 2-4 years of experience in game analytics or related analysis.
#    - **Skills**:
#      - Proficient in analytical tools (SQL, Tableau, etc.).
#      - Strong background in game monetization strategies.
#      - Ability to generate insights from player behaviour data.
#
# ### Budget
#
# 1. **Salaries**:
#    - Product Managers: $90,000 - $120,000 each
#    - Associate Product Managers: $70,000 - $90,000 each
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 2 Product Managers: $240,000 - $240,000
#    - For 2 Associate Product Managers: $140,000 - $180,000
#    - UX Designer: $80,000 - $100,000
#    - Game Analyst: $70,000 - $85,000
#    - **Overall Total**: $700,000 - $865,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# In summary, we aim to build a cross-functional team that combines product management expertise with design and analytical skills. This structured approach will ensure that we efficiently address market needs and successfully launch our new game.
#
# Please let me know if you need any further information or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Product
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: engineering_agent
#
# engineering_agent (to chat_manager):
#
# Subject: Hiring Requirements for Engineering Team - New B2C Tech Product Development
#
# Dear HR Team,
#
# As we embark on the development of our new B2C tech product, it’s essential to assemble a skilled engineering team to drive this initiative forward. Below are the key roles, qualifications, skills, and budgetary considerations required for the team.
#
# ### Key Roles and Requirements
#
# 1. **Software Engineer (3 Positions)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 3-5 years of experience in software development.
#    - **Skills**:
#      - Proficiency in programming languages (e.g., Java, Python, JavaScript).
#      - Experience with web and mobile application development.
#      - Familiarity with version control systems (e.g., Git).
#      - Understanding of RESTful APIs and microservices architecture.
#
# 2. **DevOps Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, IT, or related field.
#      - 3-5 years of experience in DevOps or systems administration.
#    - **Skills**:
#      - Experience with cloud services (AWS, Azure, GCP).
#      - Proficiency in CI/CD tools (e.g., Jenkins, GitLab CI).
#      - Strong scripting skills (e.g., Bash, Python).
#      - Familiarity with container technologies (Docker, Kubernetes).
#
# 3. **UI/UX Developer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Design, Computer Science, or related field.
#      - 2-4 years of experience in UI/UX design for web/mobile applications.
#    - **Skills**:
#      - Proficiency in design tools (e.g., Adobe XD, Figma).
#      - Strong understanding of user-centered design principles.
#      - Ability to collaborate with developers to implement designs effectively.
#
# 4. **Quality Assurance Engineer (1 Position)**
#    - **Qualifications**:
#      - Bachelor’s degree in Computer Science, Engineering, or related field.
#      - 2-4 years of experience in software quality assurance.
#    - **Skills**:
#      - Experience with automated testing frameworks (e.g., Selenium, JUnit).
#      - Strong analytical and problem-solving skills.
#      - Familiarity with performance testing tools.
#
# ### Budget
#
# 1. **Salaries**:
#    - Software Engineers: $90,000 - $120,000 each
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#
# 2. **Total Estimated Salary Budget**:
#    - For 3 Software Engineers: $270,000 - $360,000
#    - DevOps Engineer: $100,000 - $130,000
#    - UI/UX Developer: $80,000 - $100,000
#    - Quality Assurance Engineer: $70,000 - $90,000
#    - **Overall Total**: $620,000 - $780,000 annually
#
# 3. **Additional Costs**:
#    - Recruitment fees (if applicable), tools/software licenses, and potential training budgets.
#
# ### Summary
#
# Building a skilled engineering team is critical to the successful development of our new B2C product. This structured approach will ensure we attract the right talent with the necessary skills to bring our vision to life.
#
# Please let me know if you require further details or adjustments to this outline.
#
# Best regards,
#
# [Your Name]
# Head of Engineering
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# Next speaker: marketing_agent
#
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# marketing_agent (to digital_marketing_agent):
#
# Gather hiring requirements of your team for this product
#
# --------------------------------------------------------------------------------
# digital_marketing_agent (to marketing_agent):
#
# Subject: Hiring Requirements for Digital Marketing Team
#
# Hi [Marketing Head's Name],
#
# As we move forward with the development of our new B2C tech product, I’d like to outline the key hiring requirements for assembling an effective digital marketing team. This team will be critical in promoting our product and driving customer engagement. Below are the proposed roles, qualifications, skills, and budget considerations for our initiative.
#
# ### Key Roles and Responsibilities
#
# 1. **Digital Marketing Manager**
#    - **Qualifications:** Bachelor’s degree in Marketing, Business, or related field; 5+ years of digital marketing experience.
#    - **Skills:** Strong leadership, strategic planning, and analytics skills; proficiency in digital marketing tools (Google Analytics, SEMrush, HubSpot, etc.).
#    - **Budget:** $80,000 - $100,000/year
#
# 2. **Content Marketing Specialist**
#    - **Qualifications:** Bachelor’s degree in English, Marketing, or Communications; 2+ years of content creation experience.
#    - **Skills:** Excellent writing and editing; knowledge of SEO best practices; capable of creating various types of content (blogs, social media, video scripts).
#    - **Budget:** $50,000 - $70,000/year
#
# 3. **Social Media Manager**
#    - **Qualifications:** Bachelor’s degree in Marketing or Communication; 3+ years of experience managing social media platforms.
#    - **Skills:** Expertise in social media tools (Hootsuite, Buffer); ability to create and execute engaging marketing campaigns; strong analytical skills for measuring campaign success.
#    - **Budget:** $55,000 - $75,000/year
#
# 4. **PPC Specialist**
#    - **Qualifications:** Bachelor’s degree in Marketing or related field; 2+ years managing paid advertising campaigns.
#    - **Skills:** Proficiency in Google Ads, Facebook Ads, and other PPC platforms; strong analytical and problem-solving skills.
#    - **Budget:** $60,000 - $80,000/year
#
# 5. **SEO Specialist**
#    - **Qualifications:** Bachelor’s degree in Marketing or IT; 2+ years experience in SEO strategies.
#    - **Skills:** Strong understanding of SEO tools (Ahrefs, Moz); experience in keyword research and on-page/off-page optimization.
#    - **Budget:** $60,000 - $80,000/year
#
# 6. **Email Marketing Specialist**
#    - **Qualifications:** Bachelor’s degree in Marketing or Communications; 2+ years of email marketing experience.
#    - **Skills:** Knowledge of email marketing best practices; familiarity with email platforms (Mailchimp, Klaviyo); strong copywriting and analytical skills.
#    - **Budget:** $50,000 - $70,000/year
#
# ### Total Budget Estimation
# With the proposed roles, we anticipate a total budget of approximately **$405,000 - $475,000** annually. This includes salaries and potential additional costs for tools and training.
#
# ### Next Steps
# Please review these requirements and let me know if you would like to discuss any changes or additions. Once approved, we can initiate the recruitment process and ensure we have the right talent in place to drive the success of our new product.
#
# Thank you!
#
# Best regards,
# [Your Name]
# Digital Marketing Head
# [Your Company]
# [Your Contact Information]
#
#
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (09d937df-697b-40a9-9dcb-c403416f1d83): Maximum turns (1) reached
#
# ********************************************************************************
# Starting a new chat....
#
# ********************************************************************************
# marketing_agent (to creative_team_agent):
#
# Gather hiring requirements of your team for this product
# Context:
# The hiring requirements for the digital marketing team for the new B2C tech product include six key roles: Digital Marketing Manager, Content Marketing Specialist, Social Media Manager, PPC Specialist, SEO Specialist, and Email Marketing Specialist. The expected total budget for these positions ranges from $405,000 to $475,000 annually. Each role has specified qualifications, skills, and salary ranges. The next step is to review these requirements and initiate the recruitment process once approved.
#
# --------------------------------------------------------------------------------
# creative_team_agent (to marketing_agent):
#
# Subject: Hiring Requirements for Creative Team for New B2C Tech Product
#
# Dear [Marketing Head's Name],
#
# I hope this message finds you well. To successfully support the launch of our new B2C tech product, it's essential to assemble a dedicated creative team with diverse skills. Below are the key roles, qualifications, skills, and estimated budget required for this initiative.
#
# ### Key Roles and Requirements:
#
# 1. **Creative Director**
#    - **Qualifications**: Bachelor’s degree in Design, Marketing, or related field; 7+ years in creative roles.
#    - **Skills**: Strong leadership, vision creation, brand storytelling, and project management.
#    - **Salary Range**: $100,000 - $120,000
#
# 2. **Graphic Designer**
#    - **Qualifications**: Bachelor’s degree in Graphic Design or Visual Arts; 3-5 years of experience.
#    - **Skills**: Proficiency in Adobe Creative Suite, strong portfolio, understanding of branding and visual identity.
#    - **Salary Range**: $55,000 - $70,000
#
# 3. **Copywriter**
#    - **Qualifications**: Bachelor’s degree in English, Marketing, or related field; 3+ years of content creation experience.
#    - **Skills**: Excellent writing and editing skills, SEO knowledge, storytelling, and brand voice adaptability.
#    - **Salary Range**: $50,000 - $65,000
#
# 4. **UX/UI Designer**
#    - **Qualifications**: Degree in Web Design, Interaction Design, or related field; 3+ years of experience.
#    - **Skills**: Strong understanding of user experience principles, proficiency in design tools, and wireframing.
#    - **Salary Range**: $70,000 - $90,000
#
# 5. **Video Producer/Editor**
#    - **Qualifications**: Degree in Film, Media Production, or related field; 3-5 years of experience in video production.
#    - **Skills**: Proficient with video editing software, strong storytelling ability, and experience with various video formats.
#    - **Salary Range**: $60,000 - $80,000
#
# 6. **Brand Strategist**
#    - **Qualifications**: Bachelor’s degree in Marketing, Business, or related field; 5+ years of branding experience.
#    - **Skills**: Market research, brand positioning, strategic planning, and consumer psychology.
#    - **Salary Range**: $80,000 - $100,000
#
# ### Estimated Total Budget:
# The total budget for assembling the creative team is projected to be between **$415,000 and $525,000** annually, depending on the experience level and skill sets of selected candidates.
#
# ### Next Steps:
# Please review this proposal, and upon your approval, we can initiate the recruitment process to build our creative team promptly.
#
# Thank you for your support.
#
# Best regards,
#
# [Your Name]
# Creative Team Head
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (b9844334-db3e-4087-86c3-f44b17952d48): Maximum turns (1) reached
# marketing_agent (to chat_manager):
#
# Subject: Hiring Requirements for Creative Team for New B2C Tech Product
#
# Dear [Marketing Head's Name],
#
# I hope this message finds you well. To successfully support the launch of our new B2C tech product, it's essential to assemble a dedicated creative team with diverse skills. Below are the key roles, qualifications, skills, and estimated budget required for this initiative.
#
# ### Key Roles and Requirements:
#
# 1. **Creative Director**
#    - **Qualifications**: Bachelor’s degree in Design, Marketing, or related field; 7+ years in creative roles.
#    - **Skills**: Strong leadership, vision creation, brand storytelling, and project management.
#    - **Salary Range**: $100,000 - $120,000
#
# 2. **Graphic Designer**
#    - **Qualifications**: Bachelor’s degree in Graphic Design or Visual Arts; 3-5 years of experience.
#    - **Skills**: Proficiency in Adobe Creative Suite, strong portfolio, understanding of branding and visual identity.
#    - **Salary Range**: $55,000 - $70,000
#
# 3. **Copywriter**
#    - **Qualifications**: Bachelor’s degree in English, Marketing, or related field; 3+ years of content creation experience.
#    - **Skills**: Excellent writing and editing skills, SEO knowledge, storytelling, and brand voice adaptability.
#    - **Salary Range**: $50,000 - $65,000
#
# 4. **UX/UI Designer**
#    - **Qualifications**: Degree in Web Design, Interaction Design, or related field; 3+ years of experience.
#    - **Skills**: Strong understanding of user experience principles, proficiency in design tools, and wireframing.
#    - **Salary Range**: $70,000 - $90,000
#
# 5. **Video Producer/Editor**
#    - **Qualifications**: Degree in Film, Media Production, or related field; 3-5 years of experience in video production.
#    - **Skills**: Proficient with video editing software, strong storytelling ability, and experience with various video formats.
#    - **Salary Range**: $60,000 - $80,000
#
# 6. **Brand Strategist**
#    - **Qualifications**: Bachelor’s degree in Marketing, Business, or related field; 5+ years of branding experience.
#    - **Skills**: Market research, brand positioning, strategic planning, and consumer psychology.
#    - **Salary Range**: $80,000 - $100,000
#
# ### Estimated Total Budget:
# The total budget for assembling the creative team is projected to be between **$415,000 and $525,000** annually, depending on the experience level and skill sets of selected candidates.
#
# ### Next Steps:
# Please review this proposal, and upon your approval, we can initiate the recruitment process to build our creative team promptly.
#
# Thank you for your support.
#
# Best regards,
#
# [Your Name]
# Creative Team Head
# [Your Company Name]
# [Your Contact Information]
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> TERMINATING RUN (a47a7a12-1945-479c-a88f-1c3203b022bf): No next speaker selected
